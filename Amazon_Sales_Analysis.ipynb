# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales = pd.read_csv("/Users/Shreeya/Desktop/Github Repos/Amazon_Sales/amazon.csv")

# %%
df_sales.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df_sales.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df_sales.shape
# Out:
# (1465, 16)

# %%
df_sales.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
df_sales['discounted_price'] = df_sales['discounted_price'].str.replace('₹','')
df_sales['discounted_price'] = df_sales['discounted_price'].str.replace(',','')
df_sales['discounted_price'] = df_sales['discounted_price'].astype('float64')

# %%
df_sales['actual_price'] = df_sales['actual_price'].str.replace('₹','')
df_sales['actual_price'] = df_sales['actual_price'].str.replace(',','')
df_sales['actual_price'] = df_sales['actual_price'].astype('float64')

# %%
df_sales['discount_percentage'] = df_sales['discount_percentage'].str.replace('%','').astype('float64')
df_sales['discount_percentage'] = df_sales['discount_percentage'] /100
df_sales['discount_percentage']
# Out:
# 0       0.64
# 1       0.43
# 2       0.90
# 3       0.53
# 4       0.61
#         ...
# 1460    0.59
# 1461    0.25
# 1462    0.28
# 1463    0.26
# 1464    0.22
# Name: discount_percentage, Length: 1465, dtype: float64

# %%
df_sales['rating'].value_counts()
# Out:
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: rating, dtype: int64

# %%
df_sales.query('rating == "|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        2499.0                 0.16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
df_sales['rating'] = df_sales['rating'].str.replace('|','4.0').astype('float64')
# Out:
# /var/folders/_d/3gzk6ht561569mlh0h_m_cth0000gn/T/ipykernel_5582/3283728809.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_sales['rating'] = df_sales['rating'].str.replace('|','4.0').astype('float64')

# %%
df_sales['rating_count'] = df_sales['rating_count'].str.replace(',','').astype('float64')

# %%
df_sales.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %%
duplicates = df_sales.duplicated()
df_sales[duplicates]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
df_sales.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df = df_sales[['product_id','product_name','category','discounted_price','actual_price',
              'discount_percentage','rating','rating_count']].copy()

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %%
category_splits = df_sales['category'].str.split('|',expand = True)
category_splits
# Out:
#                           0                           1  \
# 0     Computers&Accessories     Accessories&Peripherals
# 1     Computers&Accessories     Accessories&Peripherals
# 2     Computers&Accessories     Accessories&Peripherals
# 3     Computers&Accessories     Accessories&Peripherals
# 4     Computers&Accessories     Accessories&Peripherals
# ...                     ...                         ...
# 1460           Home&Kitchen      Kitchen&HomeAppliances
# 1461           Home&Kitchen      Kitchen&HomeAppliances
# 1462           Home&Kitchen  Heating,Cooling&AirQuality
# 1463           Home&Kitchen  Heating,Cooling&AirQuality
# 1464           Home&Kitchen      Kitchen&HomeAppliances
#
#                                2                         3          4     5  \
# 0             Cables&Accessories                    Cables  USBCables  None
# 1             Cables&Accessories                    Cables  USBCables  None
# ...

# %%
category_splits = category_splits.rename(columns = {0:'category_1', 
                                                   1:'category_2',
                                                   2:'category_3'})

# %%
df['category_1'] = category_splits['category_1']
df['category_2'] = category_splits['category_2']

# %%
df.drop(columns = 'category', inplace = True)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 0.64     4.2       24269.0
# 1             199.0         349.0                 0.43     4.0       43994.0
# 2             199.0        1899.0                 0.90     3.9        7928.0
# 3             329.0         699.0                 0.53     4.2       94363.0
# 4             154.0         399.0                 0.61     4.2       16905.0
#
#               category_1               category_2
# 0  Computers&Accessories  Accessories&Peripherals
# ...

# %%
df['category_1'].value_counts()
# Out:
# Electronics              526
# Computers&Accessories    453
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: category_1, dtype: int64

# %%
df['category_1'] = df['category_1'].str.replace('&',' & ')
df['category_1'] = df['category_1'].str.replace('OfficeProducts','Office Products')
df['category_1'] = df['category_1'].str.replace('MusicalInstruments','Musical Instruments')
df['category_1'] = df['category_1'].str.replace('HomeImprovement','Home Improvement')

# %%
df['category_2'].value_counts()
# Out:
# Accessories&Peripherals                    381
# Kitchen&HomeAppliances                     308
# HomeTheater,TV&Video                       162
# Mobiles&Accessories                        161
# Heating,Cooling&AirQuality                 116
# WearableTechnology                          76
# Headphones,Earbuds&Accessories              66
# NetworkingDevices                           34
# OfficePaperProducts                         27
# ExternalDevices&DataStorage                 18
# Cameras&Photography                         16
# HomeStorage&Organization                    16
# HomeAudio                                   16
# GeneralPurposeBatteries&BatteryChargers     14
# Accessories                                 14
# Printers,Inks&Accessories                   11
# CraftMaterials                               7
# Components                                   5
# OfficeElectronics                            4
# Electrical                                   2
# ...

# %%
df['category_2'] = df['category_2'].str.replace('&', ' & ')
df['category_2'] = df['category_2'].str.replace(',', ', ')
df['category_2'] = df['category_2'].str.replace('HomeAppliances', 'Home Appliances')
df['category_2'] = df['category_2'].str.replace('AirQuality', 'Air Quality')
df['category_2'] = df['category_2'].str.replace('WearableTechnology', 'Wearable Technology')
df['category_2'] = df['category_2'].str.replace('NetworkingDevices', 'Networking Devices')
df['category_2'] = df['category_2'].str.replace('OfficePaperProducts', 'Office Paper Products')
df['category_2'] = df['category_2'].str.replace('ExternalDevices', 'External Devices')
df['category_2'] = df['category_2'].str.replace('DataStorage', 'Data Storage')
df['category_2'] = df['category_2'].str.replace('HomeStorage', 'Home Storage')
df['category_2'] = df['category_2'].str.replace('HomeAudio', 'Home Audio')
df['category_2'] = df['category_2'].str.replace('GeneralPurposeBatteries', 'General Purpose Batteries')
df['category_2'] = df['category_2'].str.replace('BatteryChargers', 'Battery Chargers')
df['category_2'] = df['category_2'].str.replace('CraftMaterials', 'Craft Materials')
df['category_2'] = df['category_2'].str.replace('OfficeElectronics', 'Office Electronics')
df['category_2'] = df['category_2'].str.replace('PowerAccessories', 'Power Accessories')
df['category_2'] = df['category_2'].str.replace('CarAccessories', 'Car Accessories')
df['category_2'] = df['category_2'].str.replace('HomeMedicalSupplies', 'Home Medical Supplies')
df['category_2'] = df['category_2'].str.replace('HomeTheater', 'Home Theater')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 0.64     4.2       24269.0
# 1             199.0         349.0                 0.43     4.0       43994.0
# 2             199.0        1899.0                 0.90     3.9        7928.0
# 3             329.0         699.0                 0.53     4.2       94363.0
# 4             154.0         399.0                 0.61     4.2       16905.0
#
#                 category_1                 category_2
# 0  Computers & Accessories  Accessories & Peripherals
# ...

# %%
df['product_id'].str.strip()
# Out:
# 0       B07JW9H4J1
# 1       B098NS6PVG
# 2       B096MSW6CT
# 3       B08HDJ86NZ
# 4       B08CF3B7N1
#            ...
# 1460    B08L7J3T31
# 1461    B01M6453MB
# 1462    B009P2LIL4
# 1463    B00J5DYCCA
# 1464    B01486F4G6
# Name: product_id, Length: 1465, dtype: object

# %%
rating_category = []

for score in df['rating']:
    if score < 2.0 : rating_category.append('Poor')
    elif score < 3.0 : rating_category.append('Below Average')
    elif score < 4.0 : rating_category.append('Average')
    elif score < 5.0 : rating_category.append('Above Average')
    elif score == 5.0 : rating_category.append('Excellent')

# %%
df['rating_category'] = rating_category
df['rating_category'] = df['rating_category'].astype('category')

# %%
df['rating_category'] = df ['rating_category'].cat.reorder_categories(
['Below Average','Average','Above Average','Excellent'], ordered = True)

# %%
df['difference_price'] = df['actual_price'] - df['discounted_price']

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 0.64     4.2       24269.0
# 1             199.0         349.0                 0.43     4.0       43994.0
# 2             199.0        1899.0                 0.90     3.9        7928.0
# 3             329.0         699.0                 0.53     4.2       94363.0
# 4             154.0         399.0                 0.61     4.2       16905.0
#
#                 category_1                 category_2 rating_category  \
# ...

# %%
reviewers = df_sales[['user_id','user_name']]
reviewers.head()
# Out:
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...

# %%
reviewer_id = reviewers['user_id'].str.split(',',expand = False)

# %%
reviewer_id.head()
# Out:
# 0    [AG3D6O4STAQKAY2UVGEUV46KN35Q, AHMY5CWJMMK5BJR...
# 1    [AECPFYFQVRUWC3KGNLJIOREFP5LQ, AGYYVPDD7YG7FYN...
# 2    [AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA, AESFLDV2PT363T2...
# 3    [AEWAZDZZJLQUYVOVGBEUKSLXHQ5A, AG5HTSFRRE6NL3M...
# 4    [AE3Q6KSUK5P75D5HFYHCRAOLODSA, AFUGIFH5ZAFXRDS...
# Name: user_id, dtype: object

# %%
reviewer_id_exp = reviewer_id.explode()
reviewer_id_clean = reviewer_id_exp.reset_index(drop = True)
reviewer_id_clean.head()
# Out:
# 0    AG3D6O4STAQKAY2UVGEUV46KN35Q
# 1    AHMY5CWJMMK5BJRBBSNLYT3ONILA
# 2    AHCTC6ULH4XB6YHDY6PCH2R772LQ
# 3    AGYHHIERNXKA6P5T7CZLXKVPT7IQ
# 4    AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q
# Name: user_id, dtype: object

# %%
reviewer_name = reviewers['user_name'].str.split(',',expand=False)
reviewer_name.head()
# Out:
# 0    [Manav, Adarsh gupta, Sundeep, S.Sayeed Ahmed,...
# 1    [ArdKn, Nirbhay kumar, Sagar Viswanathan, Asp,...
# 2    [Kunal, Himanshu, viswanath, sai niharka, saqi...
# 3    [Omkar dhale, JD, HEMALATHA, Ajwadh a., amar s...
# 4    [rahuls6099, Swasat Borah, Ajay Wadke, Pranali...
# Name: user_name, dtype: object

# %%
reviewer_name_exp = reviewer_name.explode()
reviewer_name_separate =reviewer_name_exp.reset_index(drop = True)
reviewer_name_separate.head()
# Out:
# 0             Manav
# 1      Adarsh gupta
# 2           Sundeep
# 3    S.Sayeed Ahmed
# 4    jaspreet singh
# Name: user_name, dtype: object

# %%
df_review_id = pd.DataFrame( data = reviewer_id_clean)
df_review_name = pd.DataFrame( data = reviewer_name_separate)
df_new = pd.merge(df_review_id,df_review_name,left_index=True,right_index=True)
df_new.head()
# Out:
#                         user_id       user_name
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh

# %%
sns.set_style(style = 'darkgrid')
sns.set_palette(palette='icefire')

# %%
main_sub_category = df[['category_1','category_2','product_id']]
main_sub_category = main_sub_category.rename( columns={'category_1': 'Main_Category', 
                                                       'category_2': 'Sub_Category',
                                                      'product_id': 'Product_ID'})
main_sub_pivot = pd.pivot_table(main_sub_category, index = ['Main_Category',
                                                           'Sub_Category'],
                               aggfunc = 'count')
main_sub_pivot
# Out:
#                                                                       Product_ID
# Main_Category           Sub_Category
# Car & Motorbike         Car Accessories                                        1
# Computers & Accessories Accessories & Peripherals                            381
#                         Components                                             5
#                         External Devices & Data Storage                       18
#                         Laptops                                                1
#                         Monitors                                               2
#                         Networking Devices                                    34
#                         Printers, Inks & Accessories                          11
#                         Tablets                                                1
# Electronics             Accessories                                           14
# ...

# %%
max_main_products = df['category_1'].value_counts().head().rename_axis('category_1').reset_index(name = 'counts')

# %%
max_sub_products = df['category_2'].value_counts().head().rename_axis('category_2').reset_index(name = 'counts')

# %%
fig, ax = plt.subplots(2,1,figsize=(8,10))
fig.suptitle( 'Maximum Number of Products By Category',fontweight = 'medium',
            size = 'x-large')
sns.barplot(ax = ax[0], data=max_main_products, x = 'counts', y='category_1')
sns.barplot(ax = ax[1], data=max_sub_products, x = 'counts', y='category_2')
# Out:
# <Axes: xlabel='counts', ylabel='category_2'>

# %%
expensive_product = sns.barplot(data = df.sort_values('discounted_price',
                                                     ascending=False).head(),
                               x = 'discounted_price', y = 'product_name')
expensive_product.set_title('Top 5 Expensive Products after discount',
                           fontweight = 'bold')
plt.show()

# %%
cheap_product = sns.barplot(data = df.sort_values('discounted_price').head(),
                           x='discounted_price', y = 'product_name')
cheap_product.set_title('Top 5 Cheapest Products after discount',
                        fontweight = 'bold')
plt.show()

# %%
huge_price_diff = sns.barplot(data = df.sort_values('difference_price',
                                                   ascending=False).head(),
                             x = 'difference_price',y = 'product_name')
huge_price_diff.set_title('Top 5 products with Huge price difference',
                         fontweight = 'bold')
plt.show()

# %%
fig, ax = plt.subplots(2,1, figsize=(8,10))
fig.suptitle('Correlation Analysis between Features', fontweight = 'heavy',
            size = 'xx-large')
sns.heatmap(ax=ax[0], data = df.corr())
sns.scatterplot(ax=ax[1], data = df, y='discounted_price', x='actual_price',
               color= 'purple')
plt.subplots_adjust(hspace=0.8)
plt.show()
# Out:
# /var/folders/_d/3gzk6ht561569mlh0h_m_cth0000gn/T/ipykernel_5582/377632515.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ax=ax[0], data = df.corr())

# %%
fig, ax = plt.subplots(1, 2,figsize=(15,5))
fig.suptitle('Rating & Number of Ratings Distribution', 
             fontweight = 'heavy',size = 'xx-large')
fig.tight_layout(pad = 3.0)

sns.histplot(ax = ax[0],data = df, x = 'rating', bins = 15, 
             kde = True, color = 'orange')
sns.histplot(ax = ax[1], data=df, x= 'rating_count',bins = 15,
            kde = True, color = 'purple')

ax[0].set_title("Distribution of Rating")
ax[1].set_title("Number of Ratings Distribution")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.boxplot(ax = ax, data = df, x='rating', y='category_1')
ax.set_title("Distribution based on Main Category", 
             fontweight = 'heavy', size = 'xx-large', y = 1.03)
plt.show()

# %%
main_ratings = df.groupby(['category_1',
                           'rating_category']).agg('count').iloc[:,1].rename_axis().reset_index(name = 'Amount')

# %%
main_ratings = main_ratings.rename( columns = {'category_1': 'Main category',
                                              'rating_category': 'Rating category'})
main_ratings.head()
# Out:
#              Main category Rating category  Amount
# 0          Car & Motorbike   Below Average       0
# 1          Car & Motorbike         Average       1
# 2          Car & Motorbike   Above Average       0
# 3          Car & Motorbike       Excellent       0
# 4  Computers & Accessories   Below Average       0

# %%
fig, ax = plt.subplots(figsize = (12,7))

sns.boxplot(ax=ax, data=df, x='rating', y='category_2')

ax.set_title("Distribution based on Sub-Category", fontweight = 'heavy',
            size ='xx-large', y=1.05)
plt.show()
